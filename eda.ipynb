# %%
import pandas as pd
import numpy as np
import os
import pathlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# genero los dataframes

def sacar_tildes(oracion:str):
    '''
    oracion : str

    Recive un str y cambia todas las vocales con tilde a unas sin tilde
    '''
    
    a,b = 'áéíóúüñÁÉÍÓÚÜÑ','aeiouunAEIOUUN'
    trans = str.maketrans(a,b)
    return oracion.translate(trans)

#lista de dfs
dfs_lista = []

#dicionario con key: nombre del directorio, y value: lista con los nombres de los dfs pertenecientes a cada directorio
nombres_por_directorio = {}


direcotrio_principal = 'dataset/'
directorio = pathlib.Path(direcotrio_principal)
directorios = [fichero.name for fichero in directorio.iterdir() if fichero.is_dir()]
for dir in directorios:
    dfs=[]
    nombre_datasets = []
    ruta_seccion = 'dataset/'+dir
    with os.scandir(ruta_seccion) as ficheros:
        for fichero in ficheros:
            ruta_archivo= ruta_seccion+'/'+str(fichero)[11:-2]
            nombre_df = sacar_tildes(str(fichero)[11:-6].replace(' ','_'))
            globals()[nombre_df] = pd.read_csv(ruta_archivo)
            dfs.append(globals()[nombre_df])
            nombre_datasets.append(nombre_df)
    nombres_por_directorio[dir] = nombre_datasets
    dfs_lista.append(dfs)

# %%
direcotrio_principal = 'Dataset/'
directorio = pathlib.Path(direcotrio_principal)

dfs=[]
nombre_datasets = []


ruta_seccion = './Datasets/'

with os.scandir(ruta_seccion) as ficheros:
        for fichero in ficheros:
            ruta_archivo= ruta_seccion+'/'+str(fichero)[11:-2]
            nombre_df = str(fichero)[11:-6]
            globals()[nombre_df] = pd.read_csv(ruta_archivo,decimal='.')
            dfs.append(globals()[nombre_df])
            nombre_datasets.append(nombre_df)

# %%
nombre_datasets
# Out:
# ['olist_closed_deals_dataset',
#  'olist_customers_dataset',
#  'olist_geolocation_dataset',
#  'olist_marketing_qualified_leads_dataset',
#  'olist_orders_dataset',
#  'olist_order_items_dataset',
#  'olist_order_payments_dataset',
#  'olist_order_reviews_dataset',
#  'olist_products_dataset',
#  'olist_sellers_dataset',
#  'product_category_name_translation']

# %% [markdown]
# ### olist_closed_deals_dataset

# %%
print(nombre_datasets[0])
dfs[0]
# Out:
# olist_closed_deals_dataset
#                                mql_id                         seller_id  \
# 0    5420aad7fec3549a85876ba1c529bd84  2c43fb513632d29b3b58df74816f1b06
# 1    a555fb36b9368110ede0f043dfc3b9a0  bbb7d7893a450660432ea6652310ebb7
# 2    327174d3648a2d047e8940d7d15204ca  612170e34b97004b3ba37eae81836b4c
# 3    f5fee8f7da74f4887f5bcae2bafb6dd6  21e1781e36faf92725dde4730a88ca0f
# 4    ffe640179b554e295c167a2f6be528e0  ed8cb7b190ceb6067227478e48cf8dde
# ..                                ...                               ...
# 837  df9a2abe2ad3f2d8758b675ac8331ecf  bfcc27719640628da877db48b672b169
# 838  8723201570415eb23b4f095d8c20a27c  4a82eab98441aeb64566e2776c1fb2b6
# 839  2e57665b8faf05c967a801eb5aedfa0a  55031883943971ca22db6894574cfe2c
# 840  40955be51cc85c5a5a6cdd12b19e9f10  c0e933c238e41f0cd459d6025ee9b364
# 841  8a6492305a5fbcdcdd1a7f5a90764c07  1bba9c94eb5c4e82fba9f7286fe81025
#
#                                sdr_id                             sr_id  \
# ...

# %%
dfs[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 842 entries, 0 to 841
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   mql_id                         842 non-null    object
#  1   seller_id                      842 non-null    object
#  2   sdr_id                         842 non-null    object
#  3   sr_id                          842 non-null    object
#  4   won_date                       842 non-null    object
#  5   business_segment               841 non-null    object
#  6   lead_type                      836 non-null    object
#  7   lead_behaviour_profile         665 non-null    object
#  8   has_company                    63 non-null     object
#  9   has_gtin                       64 non-null     object
#  10  average_stock                  66 non-null     object
#  11  business_type                  832 non-null    object
# ...

# %%
dfs[0]['has_company'].unique()
# Out:
# array([nan, True, False], dtype=object)

# %% [markdown]
# * columnas de relacion:
#     - mql_id
#     - seller_id
#     - sdr_id
#     - sr_id
#
# * tipos de datos:
#     - catergoticos:
#         - nominal:
#             - business_segment
#             - lead_type
#             - lead_behaviour_profile
#             - average_stock
#             - business_type
#
#         - binarias:
#             - has_company
#             - has_gtin
#
#     - cuantitativos:
#         - discretos:
#             - declared_product_catalog_size
#         - continuos:
#             - declared_monthly_revenue
#
#     - fecha:
#         - won_date
#
#
# * Datos Faltantes:
#     - Hay valores faltantes en :
#         - business_segment(1)
#         - lead_type(6)
#         - lead_behaviour_profile(177)
#         - has_company(779)
#         - has_gtin(778)
#         - average_stock(776)
#         - business_type(10)
#         - declared_product_catalog_size(773)

# %% [markdown]
# ### olist_customers_dataset

# %%
print(nombre_datasets[1])
dfs[1]
# Out:
# olist_customers_dataset
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
# ...

# %%
dfs[1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %% [markdown]
# * columnas de relacion:
#     - customer_id
#     - customer_unique_id
#     - customer_zip_code_prefix
#
# * tipos de datos:
#     - catergoticos:
#         - nominal:
#             - customer_city
#             - customer_state
#
# * Datos Faltantes:
#     - sin datos faltantes

# %% [markdown]
# ### olist_geolocation_dataset

# %%
print(nombre_datasets[2])
dfs[2]
# Out:
# olist_geolocation_dataset
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %%
dfs[2].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %% [markdown]
# * columnas de relacion:
#     - geolocation_zip_code_prefix
#
#
# * tipos de datos:
#     - catergoticos:
#         - nominal:
#             - geolocation_city
#             - geolocation_state
#
#     - cuantitativos:
#         - continuos:
#             - geolocation_lat
#             - geolocation_lng
#
# * Datos Faltantes:
#     - Sin datos faltantes

# %% [markdown]
# ### olist_marketing_qualified_leads_dataset

# %%
print(nombre_datasets[3])
dfs[3]
# Out:
# olist_marketing_qualified_leads_dataset
#                                 mql_id first_contact_date  \
# 0     dac32acd4db4c29c230538b72f8dd87d         2018-02-01
# 1     8c18d1de7f67e60dbd64e3c07d7e9d5d         2017-10-20
# 2     b4bc852d233dfefc5131f593b538befa         2018-03-22
# 3     6be030b81c75970747525b843c1ef4f8         2018-01-22
# 4     5420aad7fec3549a85876ba1c529bd84         2018-02-21
# ...                                ...                ...
# 7995  feaba3ffcd2ff97501696c7f9a42f41c         2018-05-22
# 7996  a79cb53cd009ab92e0143b92baa2407b         2018-03-27
# 7997  68f049a23ab109c6a0f6989bb9a02994         2017-08-27
# 7998  4f8c96e2509b984329044c6682c88ee9         2017-10-06
# 7999  8a6492305a5fbcdcdd1a7f5a90764c07         2018-01-11
#
#                        landing_page_id          origin
# 0     88740e65d5d6b056e0cda098e1ea6313          social
# 1     007f9098284a86ee80ddeb25d53e0af8     paid_search
# 2     a7982125ff7aa3b2054c6e44f9d28522  organic_search
# ...

# %%
dfs[3].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   mql_id              8000 non-null   object
#  1   first_contact_date  8000 non-null   object
#  2   landing_page_id     8000 non-null   object
#  3   origin              7940 non-null   object
# dtypes: object(4)
# memory usage: 250.1+ KB

# %% [markdown]
# * columnas de relacion:
#     - mql_id
#     - landing_page_id
#
# * tipos de datos:
#     - catergoticos:
#         - nominal:
#             - origin
#
#     - fecha:
#         - first_contact_date
#
# * Datos Faltantes:
#     - Hay valores faltantes en :
#         - origin(60)

# %% [markdown]
# <b> Datos faltantes

# %%
#veo que valroes hay en la coumna 
dfs[3]['origin'].unique()
# Out:
# array(['social', 'paid_search', 'organic_search', 'email', 'unknown',
#        'referral', 'direct_traffic', 'display', nan, 'other_publicities',
#        'other'], dtype=object)

# %% [markdown]
# * Los datos faltantes no son mucho y por la naturaleza del dato (es un dato categorico) lleno la columna con con Other.

# %%
dfs[3]['origin'].fillna('Other',inplace=True)
# Out:
# array(['social', 'paid_search', 'organic_search', 'email', 'unknown',
#        'referral', 'direct_traffic', 'display', 'Other',
#        'other_publicities', 'other'], dtype=object)

# %% [markdown]
# ### olist_orders_dataset

# %%
print(nombre_datasets[4])
dfs[4]
# Out:
# olist_orders_dataset
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
# ...

# %%
dfs[4].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %% [markdown]
# * columnas de relacion:
#     - order_id
#     - customer_id
#
# * tipos de datos:
#     - catergoticos:
#         - nominal:
#             - order_status(verificar: puede ser ordinal)
#
#     - fecha:
#         - order_purchase_timestamp
#         - order_approved_at
#         - order_delivered_carrier_date
#         - order_delivered_customer_date
#         - order_estimated_delivery_date
#
# * Datos Faltantes:
#     - Hay valores faltantes en :
#         - order_approved_at(160)
#         - order_delivered_carrier_date(1783)
#         - order_delivered_customer_date(2965)

# %% [markdown]
# <b> Datos faltantes

# %% [markdown]
# <b>Elimnar

# %%
print('Porcentaje que representan los valores faltantes en order_approved_at:',160/99441)
print('Porcentaje que representan los valores faltantes en order_delivered_carrier_date:',1783/99441)
print('Porcentaje que representan los valores faltantes en order_delivered_customer_date:',2965/99441)
# Out:
# Porcentaje que representan los valores faltantes en order_approved_at: 0.0016089942780140988
# Porcentaje que representan los valores faltantes en order_delivered_carrier_date: 0.017930229985619613
# Porcentaje que representan los valores faltantes en order_delivered_customer_date: 0.02981667521444877

# %% [markdown]
# ### olist_order_items_dataset

# %%
print(nombre_datasets[5])
dfs[5]
# Out:
# olist_order_items_dataset
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
dfs[5].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %% [markdown]
# * columnas de relacion:
#     - order_id
#     - order_item_id
#     - product_id
#     - seller_id
#
# * tipos de datos:
#     - cuantitativos:
#         - continuos:
#             - price
#             - freight_value
#
#     - fecha:
#         - shipping_limit_date
#
# * Datos Faltantes:
#     - Hay valores faltantes en :
#         - Sin vaores faltantes

# %% [markdown]
# ### olist_order_payments_dataset

# %%
print(nombre_datasets[6])
dfs[6]
# Out:
# olist_order_payments_dataset
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
dfs[6].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %% [markdown]
# * columnas de relacion:
#     - order_id
#
# * tipos de datos:
#     - catergoticos:
#         - nominal:
#             - payment_type
#
#     - cuantitativos:
#         - discretos:
#             - payment_sequential
#             - payment_installments
#
#         - continuos:
#             - payment_value
#
# * Datos Faltantes:
#     - Hay valores faltantes en :
#         - Sin valores faltantes

# %% [markdown]
# ### olist_order_reviews_dataset

# %%
print(nombre_datasets[7])
dfs[7]
# Out:
# olist_order_reviews_dataset
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
dfs[7].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %% [markdown]
# * columnas de relacion:
#     - review_id
#     - order_id
#
# * tipos de datos:
#     - catergoticos:
#         - nominal:
#             - review_comment_title
#             - review_comment_message
#
#     - cuantitativos:
#         - discretos:
#             - review_score
#
#     - fecha:
#         - review_creation_date
#         - review_answer_timestamp
#
# * Datos Faltantes:
#     - Hay valores faltantes en :
#         - review_comment_title(87656)
#         - review_comment_message(58247)

# %% [markdown]
# <b> Datos faltantes

# %%
print('Porcentaje que representan los valores faltantes en review_comment_title:',87656/99224)
print('Porcentaje que representan los valores faltantes en review_comment_message:',58247/99224)
# Out:
# Porcentaje que representan los valores faltantes en review_comment_title: 0.8834153027493349
# Porcentaje que representan los valores faltantes en review_comment_message: 0.5870253164556962

# %% [markdown]
# * Veo las filas donde ambas columnas estan vacias

# %%
ambos_nulos=dfs[7][(dfs[7]['review_comment_message'].isnull()) & (dfs[7]['review_comment_title'].isnull())]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 5      15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 6      07f9bee5d1b850860defd761afa7ff16  e48aa0d2dcec3a2e87348811bcfdf22b
# ...                                 ...                               ...
# 99217  c6b270c61f67c9f7cb07d84ea8aeaf8b  48f7ee67313eda32bfcf5b9c1dd9522d
# 99218  af2dc0519de6e0720ef0c74292fb4114  d699c734a0b1c8111f2272a3f36d398c
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
#
#        review_score review_comment_title review_comment_message  \
# ...

# %%
print('Porcentaje que representan los valores faltantes en ambos es:',56518/99224)
# Out:
# Porcentaje que representan los valores faltantes en ambos es: 0.569600096750786

# %% [markdown]
# * La perdida de datos al eliminar filas por valores faltantes es muy alta
# * Eliminar las columnas enteras haria perdieramos muchos datos tambien
#
# <b> propuesta: llenar los valores faltantes con: 'Sin titulo' y 'Sin reseña' repectivamente

# %% [markdown]
# ### olist_products_dataset

# %%
print(nombre_datasets[8])
dfs[8]
# Out:
# olist_products_dataset
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
dfs[8].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
dfs[8]['product_weight_g'].unique()
# Out:
# array([ 225., 1000.,  154., ..., 1206.,  934., 1920.])

# %% [markdown]
# * columnas de relacion:
#     - product_id
#
# * tipos de datos:
#     - catergoticos:
#         - nominal:
#             - product_category_name
#
#     - cuantitativos:
#         - discretos:
#             - product_name_lenght
#             - product_description_lenght
#             - product_photos_qty
#
#         - continuos:
#             - product_weight_g
#             - product_length_cm
#             - product_height_cm
#             - product_width_cm
#
#
# * Datos Faltantes:
#     - Hay valores faltantes en:
#         - estos articulos tienen 610 valores faltantes (hay q verificar si corresponden al mismo producto):
#             - product_category_name
#             - product_name_lenght
#             - product_description_lenght
#             - product_photos_qty
#         - estos articulos tienen 2 valores faltantes (hay q verificar si corresponden al mismo producto):
#             - product_weight_g
#             - product_length_cm
#             - product_height_cm
#             - product_width_cm

# %% [markdown]
# <b>Datos faltantes

# %% [markdown]
# * Veo si los 610 valores faltantes de cada columan son del mismo producto

# %%
products_faltantes = dfs[8][(dfs[8]['product_category_name'].isnull()) & (dfs[8]['product_name_lenght'].isnull()) & (dfs[8]['product_description_lenght'].isnull()) & (dfs[8]['product_photos_qty'].isnull())]

# %%
print('Porcentaje de datos a elimina es:',610/32951)
# Out:
# Porcentaje de datos a elimina es: 0.018512336499651

# %% [markdown]
# * En efecto son del mismo producto por lo que eliminarlos seria lo mejor por no aportar nada(nohay forma de completar los datos) y el porcentaje que se pierde de datos es insignificante.

# %% [markdown]
# <b> Analizo los ultimos dos laores faltantes

# %%
dfs[8][(dfs[8]['product_weight_g'].isnull())&(dfs[8]['product_length_cm'].isnull())&(dfs[8]['product_height_cm'].isnull())&(dfs[8]['product_width_cm'].isnull())]
# Out:
#                              product_id product_category_name  \
# 8578   09ff539a621711667c43eba6a3bd8466                 bebes
# 18851  5eb564652db742ff8f28759cd8d2652a                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 8578                  60.0                       865.0                 3.0
# 18851                  NaN                         NaN                 NaN
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 8578                NaN                NaN                NaN
# 18851               NaN                NaN                NaN
#
#        product_width_cm
# 8578                NaN
# 18851               NaN

# %% [markdown]
# * el producto con product_id 5eb564652db742ff8f28759cd8d2652a tiene todas sus filas vacias. Propuesta: eliminar.
# * el producto con product_id 09ff539a621711667c43eba6a3bd8466 se puede intentar completar los datos o eliminarlo. Propuesta: eliminar, pues no hay forma de completar los datos

# %% [markdown]
# ### olist_sellers_dataset

# %%
print(nombre_datasets[9])
dfs[9]
# Out:
# olist_sellers_dataset
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# ...

# %%
dfs[9].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %% [markdown]
# * columnas de relacion:
#     - seller_id
#     - seller_zip_code_prefix
#
# * tipos de datos:
#     - catergoticos:
#         - nominal:
#             - seller_city
#             - seller_state
#
# * Datos Faltantes:
#     - Hay valores faltantes en :
#         - Sin valores faltantes

# %% [markdown]
# ### product_category_name_translation

# %%
print(nombre_datasets[10])
dfs[10]
# Out:
# product_category_name_translation
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %%
dfs[10].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %% [markdown]
# * columnas de relacion:
#     - product_category_name(olist_products_dataset)
#
# * tipos de datos:
#     - catergoticos:
#         - nominal:
#             - product_category_name_english
#
#
# * Datos Faltantes:
#     - Hay valores faltantes en :
#         - Sin valores faltantes

# %% [markdown]
# ### Datasets sin valores faltantes:
#     - olist_customers_dataset
#     - olist_geolocation_dataset
#     - olist_order_items_dataset
#     - olist_order_payments_dataset
#     - olist_sellers_dataset
#     - product_category_name_translation

# %%
list_products = products_faltantes['product_id'].values.tolist()
dfs[5][dfs[5].isin({'product_id':list_products})['product_id'] == True]
# dfs[5][dfs[5][['product_id']].isin(['4244733e06e7ecb4970a6e2683c13e61'])]
# list_products[0]
# Out:
#                                 order_id  order_item_id  \
# 123     0046e1d57f4c07c8c92ab26be8c3dfc0              1
# 125     00482f2670787292280e0a8153d82467              1
# 132     004f5d8f238e8908e6864b874eda3391              1
# 142     0057199db02d1a5ef41bacbf41f8f63b              1
# 171     006cb7cafc99b29548d4f412c7f9f493              1
# ...                                  ...            ...
# 112306  ff24fec69b7f3d30f9dc1ab3aee7c179              1
# 112333  ff3024474be86400847879103757d1fd              1
# 112350  ff3a45ee744a7c1f8096d2e72c1a23e4              1
# 112438  ff7b636282b98e0aa524264b295ed928              1
# 112501  ffa5e4c604dea4f0a59d19cc2322ac19              2
#
#                               product_id                         seller_id  \
# 123     ff6caf9340512b8bf6d2a2a6df032cfa  38e6dada03429a47197d5d584d793b41
# 125     a9c404971d1a5b1cbc2e4070e02731fd  702835e4b785b67a084280efca355756
# ...

# %%
1603/112650
# Out:
# 0.014229915667998225

# %%
dfs[5].shape
# Out:
# (112650, 7)
